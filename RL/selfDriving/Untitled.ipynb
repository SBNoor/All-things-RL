# %%
# !pip install gym\[box2d\] pyglet==1.3.2
# Out:
# Requirement already satisfied: gym[box2d] in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (0.21.0)
# Collecting pyglet==1.3.2
#   Downloading pyglet-1.3.2-py2.py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: future in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (from pyglet==1.3.2) (0.18.2)
# Requirement already satisfied: numpy>=1.18.0 in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.21.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (2.0.0)
# Collecting gym[box2d]
#   Downloading gym-0.20.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 16.4 MB/s eta 0:00:01
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      |████████████████████████████████| 374 kB 3.9 MB/s eta 0:00:01
# Collecting gym[box2d]
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 6.9 MB/s eta 0:00:01
# Collecting cloudpickle<1.7.0,>=1.2.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting box2d-py~=2.3.5
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      |████████████████████████████████| 374 kB 22.2 MB/s eta 0:00:01
# Collecting gym[box2d]
#   Downloading gym-0.18.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 17.3 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.7.1)
#   Downloading gym-0.18.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 13.7 MB/s eta 0:00:01
#   Downloading gym-0.17.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.6 MB/s eta 0:00:01
#   Downloading gym-0.17.2.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 8.7 MB/s eta 0:00:01
#   Downloading gym-0.17.1.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 30.3 MB/s eta 0:00:01
# Requirement already satisfied: six in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (1.16.0)
#   Downloading gym-0.17.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 14.4 MB/s eta 0:00:01
#   Downloading gym-0.16.0.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 11.2 MB/s eta 0:00:01
#   Downloading gym-0.15.7.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.3 MB/s eta 0:00:01
#   Downloading gym-0.15.6.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 13.3 MB/s eta 0:00:01
#   Downloading gym-0.15.4.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 25.5 MB/s eta 0:00:01
# Collecting cloudpickle~=1.2.0
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: opencv-python in /Users/au560049/opt/anaconda3/lib/python3.8/site-packages (from gym[box2d]) (4.5.3.56)
# Building wheels for collected packages: gym, box2d-py
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.15.4-py3-none-any.whl size=1648483 sha256=00bb50677aee52c8dd605b953a7eb466265bc8774f1ecb38928f060672a983bb
#   Stored in directory: /Users/au560049/Library/Caches/pip/wheels/9c/18/7d/c8a0742c313735e23335fa606ce951d9510ed4f12af2cb763b
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp38-cp38-macosx_10_9_x86_64.whl size=498065 sha256=dff1535e2279326c2eb616201387af34c8fcd25d71ae23ca8de40a40625bc4ad
#   Stored in directory: /Users/au560049/Library/Caches/pip/wheels/cc/4f/d6/44eb0a9e6fea384e58f19cb0c4125e46a23af2b33fe3a7e81c
# Successfully built gym box2d-py
# Installing collected packages: pyglet, cloudpickle, gym, box2d-py
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 1.5.21
#     Uninstalling pyglet-1.5.21:
#       Successfully uninstalled pyglet-1.5.21
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.0.0
#     Uninstalling cloudpickle-2.0.0:
#       Successfully uninstalled cloudpickle-2.0.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.21.0
#     Uninstalling gym-0.21.0:
#       Successfully uninstalled gym-0.21.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 4.2.5 requires pyqt5<5.13, which is not installed.
# spyder 4.2.5 requires pyqtwebengine<5.13, which is not installed.
# stable-baselines3 1.2.0 requires gym>=0.17, but you have gym 0.15.4 which is incompatible.
# distributed 2021.8.1 requires cloudpickle>=1.5.0, but you have cloudpickle 1.2.2 which is incompatible.
# Successfully installed box2d-py-2.3.8 cloudpickle-1.2.2 gym-0.15.4 pyglet-1.3.2

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = "CarRacing-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 2
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1199..1503 -> 304-tiles track
# Episode:1 Score:-37.29372937293787
# Track generation: 1119..1403 -> 284-tiles track
# Episode:2 Score:-29.328621908127705

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# array([0.75573856, 0.5230841 , 0.89824694], dtype=float32)

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=40000)
# Out:
# Track generation: 1095..1376 -> 281-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1132..1427 -> 295-tiles track
# Logging to Training/Logs/PPO_1
# Track generation: 1288..1614 -> 326-tiles track
# Track generation: 1127..1413 -> 286-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -56.2    |
# | time/              |          |
# |    fps             | 42       |
# |    iterations      | 1        |
# |    time_elapsed    | 48       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1032..1294 -> 262-tiles track
# Track generation: 1064..1334 -> 270-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -47.9        |
# | time/                   |              |
# |    fps                  | 40           |
# |    iterations           | 2            |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0044952994 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | -0.00455     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.226        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0035      |
# |    std                  | 0.996        |
# |    value_loss           | 0.872        |
# ------------------------------------------
# Track generation: 1271..1593 -> 322-tiles track
# Track generation: 1341..1688 -> 347-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.5       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 3           |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.005772938 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0827      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0062     |
# |    std                  | 0.995       |
# |    value_loss           | 0.654       |
# -----------------------------------------
# Track generation: 1009..1266 -> 257-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.2       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 4           |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008820031 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.156       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.985       |
# |    value_loss           | 0.479       |
# -----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1227..1538 -> 311-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.1       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 5           |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009954484 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.0763      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0656      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.978       |
# |    value_loss           | 0.465       |
# -----------------------------------------
# Track generation: 1028..1289 -> 261-tiles track
# Track generation: 1040..1309 -> 269-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -42.3       |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 6           |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013615491 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.102       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0415      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.983       |
# |    value_loss           | 0.371       |
# -----------------------------------------
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1382..1731 -> 349-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -42.4     |
# | time/                   |           |
# |    fps                  | 36        |
# |    iterations           | 7         |
# |    time_elapsed         | 388       |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0184726 |
# |    clip_fraction        | 0.173     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.19     |
# |    explained_variance   | 0.294     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0436    |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -0.0286   |
# |    std                  | 0.973     |
# |    value_loss           | 0.409     |
# ---------------------------------------
# Track generation: 1277..1600 -> 323-tiles track
# Track generation: 1146..1437 -> 291-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -42.4       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 8           |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015752144 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.312       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0199     |
# |    std                  | 0.961       |
# |    value_loss           | 0.445       |
# -----------------------------------------
# Track generation: 1228..1539 -> 311-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -40.8       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 9           |
# |    time_elapsed         | 495         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026895687 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0181      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0333     |
# |    std                  | 0.953       |
# |    value_loss           | 0.244       |
# -----------------------------------------
# Track generation: 1071..1343 -> 272-tiles track
# Track generation: 1171..1468 -> 297-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -42         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 10          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.027011463 |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.471       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00374    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0372     |
# |    std                  | 0.942       |
# |    value_loss           | 0.32        |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1259..1578 -> 319-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -43.7       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 11          |
# |    time_elapsed         | 604         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.031574965 |
# |    clip_fraction        | 0.254       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0472      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0358     |
# |    std                  | 0.935       |
# |    value_loss           | 0.259       |
# -----------------------------------------
# Track generation: 1156..1449 -> 293-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.2       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 12          |
# |    time_elapsed         | 660         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.030555313 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.442       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0109     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0349     |
# |    std                  | 0.927       |
# |    value_loss           | 0.19        |
# -----------------------------------------
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1335..1673 -> 338-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.4       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 13          |
# |    time_elapsed         | 714         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.035438914 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0319     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0357     |
# |    std                  | 0.914       |
# |    value_loss           | 0.198       |
# -----------------------------------------
# Track generation: 1142..1431 -> 289-tiles track
# Track generation: 1075..1353 -> 278-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.8       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 14          |
# |    time_elapsed         | 771         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.035499744 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0348      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0354     |
# |    std                  | 0.906       |
# |    value_loss           | 0.218       |
# -----------------------------------------
# Track generation: 1235..1548 -> 313-tiles track
# Track generation: 1289..1616 -> 327-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 15          |
# |    time_elapsed         | 826         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.032341022 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0331     |
# |    std                  | 0.898       |
# |    value_loss           | 0.163       |
# -----------------------------------------
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -49.1      |
# | time/                   |            |
# |    fps                  | 37         |
# |    iterations           | 16         |
# |    time_elapsed         | 880        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.02176099 |
# |    clip_fraction        | 0.246      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.9       |
# |    explained_variance   | 0.564      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00959    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0231    |
# |    std                  | 0.881      |
# |    value_loss           | 0.126      |
# ----------------------------------------
# Track generation: 1097..1383 -> 286-tiles track
# Track generation: 1172..1469 -> 297-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.9       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 17          |
# |    time_elapsed         | 935         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.030989582 |
# |    clip_fraction        | 0.272       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0053      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0327     |
# |    std                  | 0.872       |
# |    value_loss           | 0.135       |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 18          |
# |    time_elapsed         | 989         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.026460141 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00532    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0201     |
# |    std                  | 0.864       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# Track generation: 1070..1344 -> 274-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1217..1525 -> 308-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.5       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 19          |
# |    time_elapsed         | 1046        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.029269498 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0481     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 0.861       |
# |    value_loss           | 0.0991      |
# -----------------------------------------
# Track generation: 1192..1494 -> 302-tiles track
# Track generation: 1058..1334 -> 276-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 20          |
# |    time_elapsed         | 1103        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.024121152 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.493       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00301    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0291     |
# |    std                  | 0.848       |
# |    value_loss           | 0.169       |
# -----------------------------------------

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)
# Out:
# /Users/au560049/opt/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'Training/Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /Users/au560049/opt/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1112..1394 -> 282-tiles track
# Track generation: 1071..1346 -> 275-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1277..1600 -> 323-tiles track
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1328..1664 -> 336-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# Track generation: 1115..1397 -> 282-tiles track
# (-57.21921327114105, 17.91718078739937)

# %%
env.close()

# %%
import numpy as np
import torch
obs = env.reset()
print(type(obs))
# Out:
# Track generation: 1169..1472 -> 303-tiles track
# <class 'numpy.ndarray'>

# %%
obs1 = np.asarray(torch.from_numpy(obs.copy()))
print(type(obs1))
# Out:
# <class 'numpy.ndarray'>

# %%
#obs = env.reset()
while True:
    action, _states = model.predict(obs1)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hb/z8rgp2ms555696jbfd6vljxh1gx31y/T/ipykernel_13322/322330861.py in <module>
#       2 while True:
#       3     action, _states = model.predict(obs1)
# ----> 4     obs, rewards, dones, info = env.step(action)
#       5     env.render()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/box2d/car_racing.py in step(self, action)
#     321         self.t += 1.0/FPS
#     322
# --> 323         self.state = self.render("state_pixels")
#     324
#     325         step_reward = 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/box2d/car_racing.py in render(self, mode)
#     394         self.render_road()
#     395         for geom in self.viewer.onetime_geoms:
# --> 396             geom.render()
#     397         self.viewer.onetime_geoms = []
#     398         t.disable()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py in render(self)
#     164     def render(self):
#     165         for attr in reversed(self.attrs):
# --> 166             attr.enable()
#     167         self.render1()
#     168         for attr in self.attrs:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/classic_control/rendering.py in enable(self)
#     204         self.vec4 = vec4
#     205     def enable(self):
# --> 206         glColor4f(*self.vec4)
#     207
#     208 class LineStyle(Attr):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#      83     pass
#      84
# ---> 85 def errcheck(result, func, arguments):
#      86     if _debug_gl_trace:
#      87         try:
#
# KeyboardInterrupt:

# %%
env.close()

# %%
env = gym.make('SpaceInvaders-v0')
height, width, channels = env.observation_space.shape
actions = env.action_space.n
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/folders/hb/z8rgp2ms555696jbfd6vljxh1gx31y/T/ipykernel_13322/1144688393.py in <module>
# ----> 1 env = gym.make('SpaceInvaders-v0')
#       2 height, width, channels = env.observation_space.shape
#       3 actions = env.action_space.n
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/registration.py in make(id, **kwargs)
#     154
#     155 def make(id, **kwargs):
# --> 156     return registry.make(id, **kwargs)
#     157
#     158 def spec(id):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/registration.py in make(self, path, **kwargs)
#      99             logger.info('Making new env: %s', path)
#     100         spec = self.spec(path)
# --> 101         env = spec.make(**kwargs)
#     102         # We used to have people override _reset/_step rather than
#     103         # reset/step. Set _gym_disable_underscore_compat = True on
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/registration.py in make(self, **kwargs)
#      71         else:
#      72             cls = load(self.entry_point)
# ---> 73             env = cls(**_kwargs)
#      74
#      75         # Make the enviroment aware of which spec it came from.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/gym/envs/atari/atari_env.py in __init__(self, game, mode, difficulty, obs_type, frameskip, repeat_action_probability, full_action_space)
#      47
#      48         self.game = game
# ---> 49         self.game_path = atari_py.get_game_path(game)
#      50         self.game_mode = mode
#      51         self.game_difficulty = difficulty
#
# ~/opt/anaconda3/lib/python3.8/site-packages/atari_py/games.py in get_game_path(game_name)
#      18     path = os.path.join(_games_dir, game_name) + ".bin"
#      19     if not os.path.exists(path):
# ---> 20         raise Exception('ROM is missing for %s, see https://github.com/openai/atari-py#roms for instructions' % (game_name,))
#      21     return path
#      22
#
# Exception: ROM is missing for space_invaders, see https://github.com/openai/atari-py#roms for instructions
